# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("master.csv")
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
del df['country-year']
del df['HDI for year']
del df[' gdp_for_year ($) ']
del df['generation']
del df['suicides/100k pop']
del df['gdp_per_capita ($)']
df.head()
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300

# %%
lst=set(df['country'])
#print(lst)
con=dict()
i=0
for country in lst:
    con[country]=i
    i=i+1
print(con)
df.head()
# Out:
# {'Russian Federation': 0, 'Armenia': 1, 'Italy': 2, 'Seychelles': 3, 'Germany': 4, 'Bahrain': 5, 'Israel': 6, 'Mauritius': 7, 'Kyrgyzstan': 8, 'Belize': 9, 'Suriname': 10, 'Serbia': 11, 'Singapore': 12, 'Aruba': 13, 'Cyprus': 14, 'Finland': 15, 'Kazakhstan': 16, 'Sri Lanka': 17, 'Hungary': 18, 'Lithuania': 19, 'Jamaica': 20, 'Kuwait': 21, 'Japan': 22, 'United States': 23, 'France': 24, 'Mexico': 25, 'Belgium': 26, 'Australia': 27, 'Austria': 28, 'Uzbekistan': 29, 'Malta': 30, 'Spain': 31, 'Dominica': 32, 'Oman': 33, 'Slovakia': 34, 'Grenada': 35, 'Saint Vincent and Grenadines': 36, 'United Kingdom': 37, 'Denmark': 38, 'Kiribati': 39, 'Trinidad and Tobago': 40, 'Ecuador': 41, 'Qatar': 42, 'New Zealand': 43, 'San Marino': 44, 'Slovenia': 45, 'Colombia': 46, 'Latvia': 47, 'Albania': 48, 'Saint Lucia': 49, 'Panama': 50, 'Ireland': 51, 'Bulgaria': 52, 'United Arab Emirates': 53, 'Thailand': 54, 'Romania': 55, 'Belarus': 56, 'Maldives': 57, 'Portugal': 58, 'Sweden': 59, 'Cabo Verde': 60, '
# ...

# %%
df.replace({"country":con},inplace=True)

# %%
df.age[df.age=='5-14 years']=1
df.age[df.age=='15-24 years']=2
df.age[df.age=='25-34 years']=3
df.age[df.age=='35-54 years']=4
df.age[df.age=='55-74 years']=5
df.age[df.age=='75+ years']=6
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
df.sex[df.sex=='male']=1
df.sex[df.sex=='female']=2
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    country  year sex age  suicides_no  population
# 0       48  1987   1   2           21      312900
# 1       48  1987   1   4           16      308000
# 2       48  1987   2   2           14      289700
# 3       48  1987   1   6            1       21800
# 4       48  1987   1   3            9      274300

# %%
df.to_csv('final.csv',encoding='utf-8')

# %%
df.head()
# Out:
#    country  year sex age  suicides_no  population
# 0       48  1987   1   2           21      312900
# 1       48  1987   1   4           16      308000
# 2       48  1987   2   2           14      289700
# 3       48  1987   1   6            1       21800
# 4       48  1987   1   3            9      274300

# %%
data = pd.read_csv('final.csv')
print(data.shape)
data.head()
del data['Unnamed: 0']
data.head()
# Out:
# (27820, 7)
#    country  year  sex  age  suicides_no  population
# 0       48  1987    1    2           21      312900
# 1       48  1987    1    4           16      308000
# 2       48  1987    2    2           14      289700
# 3       48  1987    1    6            1       21800
# 4       48  1987    1    3            9      274300

# %%
colnames = ['country', 'year', 'sex', 'age', 'rate', 'population']
data.columns = colnames
data.head()
# Out:
#    country  year  sex  age  rate  population
# 0       48  1987    1    2    21      312900
# 1       48  1987    1    4    16      308000
# 2       48  1987    2    2    14      289700
# 3       48  1987    1    6     1       21800
# 4       48  1987    1    3     9      274300

# %%
def plotFeatures(col_list,title):
    plt.figure(figsize=(10, 14))
    i = 0
    print(len(col_list))
    for col in col_list:
        i+=1
        plt.subplot(7,2,i)
        plt.plot(data[col],data["rate"],marker='.',linestyle='none')
        plt.title(title % (col))   
        plt.tight_layout()
#in [11]:
colnames = ['country', 'year', 'sex', 'age', 'population']
plotFeatures(colnames,"Relationship bw %s and sucide rate")
# Out:
# 5
